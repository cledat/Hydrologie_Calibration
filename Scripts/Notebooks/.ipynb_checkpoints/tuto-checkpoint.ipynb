# %% [markdown]
# # Tutorial notebook

# %% [markdown]
# ## Imports

# %%
import numpy as np
import xarray as xr
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ouverture des fichiers

# %%
output_path = "/work/ch0636/g300128/output-files/danube_output/"
context_path = "/work/ch0636/g300128/output-files/danube_output/"
#name = "act_bigLakeResAbst_daily.nc"
name = "IceMelt_daily.nc"
path_danube = "/work/ch0636/projects/uwares/CWatM_input/CWatM-Earth-30min/init/Danube_19981231.nc"

# %%
ds = xr.open_dataset(path_danube)

# %%
da = xr.open_rasterio('/work/ch0636/g300128/output-files/danube_output2/basin.tif')

# %% [markdown]
# ## Traitement des fichiers

# %%
ds.SnowCover1.plot()
